# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
pwd
# Out:
# 'C:\\Users\\Raju'

# %%
import pandas as pd
data = pd.read_csv('C:/Users/Raju/downloads/nba.csv',index_col = "Position")
#first = data.loc["C"]
#sortind data
#data.sort_values("Name",axis = 0,ascending = True,inplace = True,na_position="last")
#new  = data.rename(columns = {"Team":"Team1"})
#data.drop("Name",axis =1,inplace  =True)
#data.pop("Age")

#data.size
#data.ndim
#data["Rank"] = data["Age"].rank()
#data.sort_values("Age",inplace = True)
data.drop_duplicates(subset = "Name",keep = False,inplace = True)
data
# Out:
#                    Name            Team  Number   Age Height  Weight  \
# Position
# PG        Avery Bradley  Boston Celtics     0.0  25.0    6-2   180.0
# SF          Jae Crowder  Boston Celtics    99.0  25.0    6-6   235.0
# SG         John Holland  Boston Celtics    30.0  27.0    6-5   205.0
# SG          R.J. Hunter  Boston Celtics    28.0  22.0    6-5   185.0
# PF        Jonas Jerebko  Boston Celtics     8.0  29.0   6-10   231.0
# ...                 ...             ...     ...   ...    ...     ...
# PG         Shelvin Mack       Utah Jazz     8.0  26.0    6-3   203.0
# PG            Raul Neto       Utah Jazz    25.0  24.0    6-1   179.0
# C          Tibor Pleiss       Utah Jazz    21.0  26.0    7-3   256.0
# C           Jeff Withey       Utah Jazz    24.0  26.0    7-0   231.0
# NaN                 NaN             NaN     NaN   NaN    NaN     NaN
#
#                     College     Salary
# Position
# PG                    Texas  7730337.0
# ...

# %%
dfs = data.sample(10)
dfs.sort_index(axis=0)
dfs.insert(0,"indexes","raju")
dfs
# Out:
#          indexes                  Team  Number Height  Weight  \
# Position
# PF          raju      Dallas Mavericks    42.0    6-9   245.0
# PF          raju     Memphis Grizzlies     7.0   6-10   245.0
# PG          raju         Orlando Magic     4.0    6-4   185.0
# PF          raju   Cleveland Cavaliers     9.0   6-11   255.0
# SF          raju        Indiana Pacers     0.0    6-6   231.0
# PG          raju  Los Angeles Clippers     3.0    6-0   175.0
# C           raju     Memphis Grizzlies    33.0    7-1   255.0
# SF          raju            Miami Heat    11.0    6-9   205.0
# PF          raju    Los Angeles Lakers     2.0    6-8   250.0
# SF          raju     San Antonio Spurs     1.0    6-9   230.0
#
#                       College      Salary
# Position
# PF                    Florida   2085671.0
# PF              Blinn College   5000000.0
# PG        Louisiana-Lafayette   2505720.0
# PF                    Arizona   8193029.0
# SF                        NaN   4394225.0
# ...

# %%
import pandas as pd
df = data.rename(columns = {"Team" : "team","salary":"income"},inplace =True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-2075e913c6eb> in <module>
#       1 import pandas as pd
# ----> 2 df = data.rename(columns = {"Team" : "team","salary":"income"},inplace =True)
#       3 df
#
# AttributeError: 'dict' object has no attribute 'rename'

# %%
import pandas as pd
import numpy as np
data = dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
#df.replace(t0_replace = 3,value = 4)
#df.fillna()
#df.interpoloate()
#df.dropna()
#df.isnull()
#df.isnotnull()
 #df["Second score"].interpolate(method = 'linear")

# %%
# iteration in pandas
import pandas as pd 
import numpy as np
data = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
df = pd.DataFrame(data)
#iterrows()
#iteritems()
#itertuples
for i in df.iteritems():
    print(i)
# Out:
# ('name', 0    aparna
# 1    pankaj
# 2    sudhir
# 3     Geeku
# Name: name, dtype: object)
# ('degree', 0       MBA
# 1       BCA
# 2    M.Tech
# 3       MBA
# Name: degree, dtype: object)
# ('score', 0    90
# 1    40
# 2    80
# 3    98
# Name: score, dtype: int64)

# %%
c = list(df)
for i in c:
    print(df[i][2])
# Out:
# sudhir
# M.Tech
# 80

# %%
import pandas as pd
import numpy as np
data  ={'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"]}
df = pd.DataFrame(data)
df.insert(2,"team","[1,2,3,4,5,6]")
df
# Out:
#      name  degree           team
# 0  aparna     MBA  [1,2,3,4,5,6]
# 1  pankaj     BCA  [1,2,3,4,5,6]
# 2  sudhir  M.Tech  [1,2,3,4,5,6]
# 3   Geeku     MBA  [1,2,3,4,5,6]

# %%
import pandas as pd
import numpy as np
np.random.seed(25)
df = pd.DataFrame(np.random.rand(10,3),columns = ['a','b','c'])
df.iloc[-1] = np.nan
df
# Out:
#           a         b         c
# 0  0.870124  0.582277  0.278839
# 1  0.185911  0.411100  0.117376
# 2  0.684969  0.437611  0.556229
# 3  0.367080  0.402366  0.113041
# 4  0.447031  0.585445  0.161985
# 5  0.520719  0.326051  0.699186
# 6  0.366395  0.836375  0.481343
# 7  0.516502  0.383048  0.997541
# 8  0.514244  0.559053  0.034450
# 9       NaN       NaN       NaN

# %%
df.add(1)
df.add(1,fill_value = 9)
# Out:
#            a          b          c
# 0   1.870124   1.582277   1.278839
# 1   1.185911   1.411100   1.117376
# 2   1.684969   1.437611   1.556229
# 3   1.367080   1.402366   1.113041
# 4   1.447031   1.585445   1.161985
# 5   1.520719   1.326051   1.699186
# 6   1.366395   1.836375   1.481343
# 7   1.516502   1.383048   1.997541
# 8   1.514244   1.559053   1.034450
# 9  10.000000  10.000000  10.000000

# %%
tk = pd.Series(np.ones(10))
tk
df.add(tk,axis = "index")
# Out:
#           a         b         c
# 0  1.870124  1.582277  1.278839
# 1  1.185911  1.411100  1.117376
# 2  1.684969  1.437611  1.556229
# 3  1.367080  1.402366  1.113041
# 4  1.447031  1.585445  1.161985
# 5  1.520719  1.326051  1.699186
# 6  1.366395  1.836375  1.481343
# 7  1.516502  1.383048  1.997541
# 8  1.514244  1.559053  1.034450
# 9       NaN       NaN       NaN

# %%
np.random.seed(10)
df1  = pd.DataFrame(np.random.rand(10,3),columns = ['a','b','c'])
df.add(df1)
df.nunique()
# Out:
# a    9
# b    9
# c    9
# dtype: int64

# %%
data = pd.read_csv('C:/Users/Raju/downloads/nba.csv')

#new = data["Number"].isin([11.0])
#data[new]
#new1 = data["Number"].isin([11.0,7.0])
#data.sort_values("Name",inplace=True)
#data1 = data["Name"].duplicated()
#data.head()
#data[data1]
#data.drop_duplicate("Age",keep = "first", )
#data.head(5)
#n = 9
#series = data["Name"]
#top = series.head(n=n)
#top
#series.tail()
data.dropna(inplace =True)
perc = [.20,.40,.60,.80]
include = ['object','float','int']
dat1 = data.describe(percentiles = perc,include = include)
desc =data["Name"].describe()
dat1
desc
gfg = pd.DataFrame(data["Weight"].head())
gfg.to_numpy
# Out:
# <bound method DataFrame.to_numpy of    Weight
# 0   180.0
# 1   235.0
# 3   185.0
# 6   235.0
# 7   238.0>

# %%
data = pd.Series(['a', 'b', 'c', 'd'])
new = data.copy()
data[1] = "changed value"
data
new
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
new
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd
import numpy as np
sr = pd.Series([12,3,4,3,43,4])
index_ =[0,2,3,4,5,6]
sr.index = index_
result = sr.as_matrix()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0b3ac52aadc4> in <module>
#       4 index_ =[0,2,3,4,5,6]
#       5 sr.index = index_
# ----> 6 result = sr.as_matrix()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'as_matrix'

# %%
data = pd.read_csv('C:/Users/Raju/downloads/nba.csv')
#data[['Name','Age']]
address = ['a','b','c']
#data["adrs"] = address
#df = pd.concat([newdata,df]).reset_index(drop= True)
small = data['Salary'].min()
small
# Out:
# 30888.0

# %%
import pandas as pd
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
df = pd.DataFrame(data)

address = ["raju","suresh","karthik","nenrika"]
#df['address'] = address
#df.insert(2,"adress",[1,2,3,3],True)
df1 = df.assign(address = [2,3,4,5])
df1
# Out:
#      Name  Height Qualification  address
# 0     Jai     5.1           Msc        2
# 1  Princi     6.2            MA        3
# 2  Gaurav     5.1           Msc        4
# 3    Anuj     5.2           Msc        5

# %%
#df = pd.DataFrame({'Weight':[45, 88, 56, 15, 71],
                   'Name':['Sam', 'Andrea', 'Alex', 'Robin', 'Kia'],
                   'Age':[14, 25, 55, 8, 21]})

index_= pd.date_range("2010-10-09 08:45",periods = 5,freq = "H")
df.index= index_
df1 = df.truncate(before = "2010-10-09 09:45",after = "2010-10-09 011:45" , copy = True)
df1
# Out:
#                      Weight    Name  Age
# 2010-10-09 09:45:00      88  Andrea   25
# 2010-10-09 10:45:00      56    Alex   55
# 2010-10-09 11:45:00      15   Robin    8

# %%
import pandas as pd
data = pd.read_csv('C:/Users/Raju/downloads/nba.csv')
data
g= data.groupby("Position")
for i,j in g:
    print(i)
    print(j)
# Out:
# C
#                Name            Team  Number Position  Age  Height  Weight  \
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 10  Jared Sullinger  Boston Celtics       7        C   24  06-Sep     260
#
#        College     Salary
# 7      Gonzaga  2165160.0
# 10  Ohio State  2569260.0
# PF
#             Name            Team  Number Position  Age  Height  Weight  \
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# 5   Amir Johnson  Boston Celtics      90       PF   29  06-Sep     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21  06-Aug     235
#
#   College      Salary
# 4     NaN   5000000.0
# 5     NaN  12000000.0
# 6     LSU   1170960.0
# PG
#              Name            Team  Number Position  Age  Height  Weight  \
# 0   Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 8    Terry Rozier  Boston Celtics      12       PG   22  06-Feb     190
# ...

# %%
g.get_group('SG')
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 12   Evan Turner  Boston Celtics      11       SG   27  06-Jul     220
# 13   James Young  Boston Celtics      13       SG   20  06-Jun     215
#
#               College     Salary
# 2   Boston University        NaN
# 3       Georgia State  1148640.0
# 12         Ohio State  3425510.0
# 13           Kentucky  1749840.0

# %%
g.max("Number")
# Out:
#           Number  Age  Weight      Salary
# Position
# C             41   25     260   2569260.0
# PF            90   29     240  12000000.0
# PG            36   27     220   7730337.0
# SF            99   25     235   6796117.0
# SG            30   27     220   3425510.0

# %%
g.mean()
# Out:
#           Number        Age      Weight        Salary
# Position
# C           24.0  24.500000  249.000000  2.367210e+06
# PF          51.0  26.333333  235.333333  6.056987e+06
# PG          13.0  24.000000  193.750000  4.974652e+06
# SF          99.0  25.000000  235.000000  6.796117e+06
# SG          20.5  24.000000  206.250000  2.107997e+06

# %%
g.describe()
# Out:
#          Number                                                  Age  \
#           count  mean        std   min   25%   50%   75%   max count
# Position
# C           2.0  24.0  24.041631   7.0  15.5  24.0  32.5  41.0   2.0
# PF          3.0  51.0  41.146081   8.0  31.5  55.0  72.5  90.0   3.0
# PG          4.0  13.0  16.124515   0.0   3.0   8.0  18.0  36.0   4.0
# SF          1.0  99.0        NaN  99.0  99.0  99.0  99.0  99.0   1.0
# SG          4.0  20.5   9.882645  11.0  12.5  20.5  28.5  30.0   4.0
#
#                      ...  Weight        Salary                              \
#                mean  ...     75%    max  count          mean           std
# Position             ...
# C         24.500000  ...  254.50  260.0    2.0  2.367210e+06  2.857419e+05
# PF        26.333333  ...  237.50  240.0    3.0  6.056987e+06  5.491352e+06
# PG        24.000000  ...  197.50  220.0    4.0  4.974652e+06  2.808176e+06
# ...

# %%
# %matplotlib inline
g.plot()
# Out:
# Position
# C     AxesSubplot(0.125,0.125;0.775x0.755)
# PF    AxesSubplot(0.125,0.125;0.775x0.755)
# PG    AxesSubplot(0.125,0.125;0.775x0.755)
# SF    AxesSubplot(0.125,0.125;0.775x0.755)
# SG    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
#pd.concat([df1,df2])
#pd.concat([df1,df2],axis  = 1,join = 'inner') adding common indexes
#re = df.append(df1)
#re = pd.concat(frames,keys=[x,y])
#re = pd.concat(frames,ignore_index = True)

# %%
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
data1 = {'Name': ['raju', 'Princi', 'nerniia', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
df1 = pd.DataFrame(data)
df2 = pd.DataFrame(data1)
re =pd.merge(df1,df2,on = "Name",how = "inner",indicator = True)
re
# Out:
#      Name  Height_x Qualification_x  Height_y Qualification_y _merge
# 0  Princi       6.2              MA       6.2              MA   both
# 1    Anuj       5.2             Msc       5.2             Msc   both

# %%
data = pd.read_csv('C:/Users/Raju/downloads/nba.csv')
data
data.pivot(index  = "Name",columns = "Team",values = "College")
data.pivot_table(index = "Position",columns = "College",aggfunc = "sum",margins = True)
# Out:
#                        Age                                                  \
# College  Boston University Georgia State Gonzaga Kentucky   LSU Louisville
# Position
# C                      NaN           NaN    25.0      NaN   NaN        NaN
# PF                     NaN           NaN     NaN      NaN  21.0        NaN
# PG                     NaN           NaN     NaN      NaN   NaN       22.0
# SF                     NaN           NaN     NaN      NaN   NaN        NaN
# SG                    27.0          22.0     NaN     20.0   NaN        NaN
# All                    NaN          22.0    25.0     20.0  21.0       22.0
#
#                                                     ...  Weight           \
# College  Marquette Ohio State Oklahoma State Texas  ... Gonzaga Kentucky
# Position                                            ...
# C              NaN       24.0            NaN   NaN  ...   238.0      NaN
# PF             NaN        NaN            NaN   NaN  ...     NaN      NaN
# ...

# %%
#df.pivot_table(index = "date",columns = " Names",aggfunc = "sum")
